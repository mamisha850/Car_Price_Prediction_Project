# %%
# !pip install selenium

# %%
import selenium
from selenium import webdriver
from selenium .webdriver.common.by import By
import pandas as pd
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
import re
 
import warnings 
warnings.filterwarnings("ignore")

# %%
driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

url='https://www.cars24.com/'
driver.get(url)

# %%
explore=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[3]/div[2]/div[1]/div[1]/img')
explore.click()

# %%
buy_used_cars=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[3]/div[2]/div[1]/div[1]/img')
buy_used_cars.click()

# %%
View_all_cars=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div[2]/button')
View_all_cars.click()

# %% [markdown]
#                                     Scraping data of different locations

# %%
#                                          NEW DELHI

b1=[]
b1_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in b1_tag:
    b1.append(i.text.split()[1])
    
m1=[]
m1_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in m1_tag:
    m1.append(i.text.split()[-1].replace('1.0','Wagon R 1.0'))
    
v1=[]
v1_tag=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in v1_tag:
    v1.append(i.text.replace('Automatic','').replace('Manual','')) 
    
y1=[]
y1_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in y1_tag:
    y1.append(i.text.split()[0])
    
k1=[]
k1_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in k1_tag:
    k1.append(i.text.split()[0].replace(',',''))
    
o1=[]
o1_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in o1_tag:
    o1.append(i.text.split()[2].replace('st','').replace('nd','').replace('rd',''))
    
f1=[]
f1_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in f1_tag:
    f1.append(i.text.split()[-1])


l1=[]
l1.append('New Delhi')
l1=l1*580

p1=[]
p1_tag=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in p1_tag:
    p1.append(i.text.replace(',','').replace('₹',''))

# %%
#                                             NOIDA

b2=[]
b2_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in b2_tag:
    b2.append(i.text.split()[1])
    
m2=[]
m2_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in m2_tag:
    m2.append(i.text.split()[-1].replace('1.0','Wagon R 1.0'))
    
v2=[]
v2_tag=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in v2_tag:
    v2.append(i.text.replace('Automatic','').replace('Manual','').replace('AUTOMATIC',''))
    
y2=[]
y2_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in y2_tag:
    y2.append(i.text.split()[0])
    
k2=[]
k2_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in k2_tag:
    k2.append(i.text.split()[0].replace(',',''))
    
o2=[]
o2_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in o2_tag:
    o2.append(i.text.split()[2].replace('st','').replace('nd','').replace('rd',''))
    
f2=[]
f2_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in f2_tag:
    f2.append(i.text.split()[-1])


l2=[]
l2.append('Noida')
l2=l2*560

p2=[]
p2_tag=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in p2_tag:
    p2.append(i.text.replace(',','').replace('₹',''))

# %%
#                                        MUMBAI

b3=[]
b3_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in b3_tag:
    b3.append(i.text.split()[1])
    
m3=[]
m3_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in m3_tag:
    m3.append(i.text.split()[-1].replace('1.0','Wagon R 1.0'))
    
v3=[]
v3_tag=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in v3_tag:
    v3.append(i.text.replace('Automatic','').replace('Manual','').replace('AUTOMATIC',''))  
    
y3=[]
y3_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in y3_tag:
    y3.append(i.text.split()[0])
    
k3=[]
k3_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in k3_tag:
    k3.append(i.text.split()[0].replace(',',''))
    
o3=[]
o3_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in o3_tag:
    o3.append(i.text.split()[2].replace('st','').replace('nd','').replace('rd',''))
    
f3=[]
f3_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in f3_tag:
    f3.append(i.text.split()[-1])


l3=[]
l3.append('Mumbai')
l3=l3*473

p3=[]
p3_tag=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in p3_tag:
    p3.append(i.text.replace(',','').replace('₹',''))

# %%
#                                               BENGALURU

b4=[]
b4_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in b4_tag:
    b1.append(i.text.split()[1])
    
m4=[]
m4_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in m4_tag:
    m4.append(i.text.split()[-1].replace('1.0','Wagon R 1.0'))
    
v4=[]
v4_tag=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in v4_tag:
    v4.append(i.text.replace('Automatic','').replace('Manual',''))    
    
y4=[]
y4_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in y4_tag:
    y4.append(i.text.split()[0])
    
k4=[]
k4_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in k4_tag:
    k4.append(i.text.split()[0].replace(',',''))
    
o4=[]
o4_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in o4_tag:
    o4.append(i.text.split()[2].replace('st','').replace('nd','').replace('rd',''))
    
f4=[]
f4_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in f4_tag:
    f4.append(i.text.split()[-1])


l4=[]
l4.append('Bengaluru')
l4=l4*570

p4=[]
p4_tag=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in p4_tag:
    p4.append(i.text.replace(',','').replace('₹',''))

# %%
#                                                  PUNE

b5=[]
b5_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in b5_tag:
    b5.append(i.text.split()[1])
    
m5=[]
m5_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in m5_tag:
    m5.append(i.text.split()[-1].replace('1.0','Wagon R 1.0'))
    
v5=[]
v5_tag=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in v5_tag:
    v5.append(i.text.replace('Automatic','').replace('Manual',''))   
    
y5=[]
y5_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in y5_tag:
    y5.append(i.text.split()[0])
    
k5=[]
k5_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in k5_tag:
    k5.append(i.text.split()[0].replace(',',''))
    
o5=[]
o5_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in o5_tag:
    o5.append(i.text.split()[2].replace('st','').replace('nd','').replace('rd',''))
    
f5=[]
f5_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in f5_tag:
    f5.append(i.text.split()[-1])

l5=[]
l5.append('Pune')
l5=l5*379

p5=[]
p5_tag=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in p5_tag:
    p5.append(i.text.replace(',','').replace('₹',''))

# %%
#                                           HYDERABAD

b6=[]
b6_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in b6_tag:
    b6.append(i.text.split()[1])
    
m6=[]
m6_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in m6_tag:
    m6.append(i.text.split()[-1].replace('1.0','Wagon R 1.0'))
    
v6=[]
v6_tag=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in v6_tag:
    v6.append(i.text.replace('Automatic','').replace('Manual','')) 
    
y6=[]
y6_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in y6_tag:
    y6.append(i.text.split()[0])
    
k6=[]
k6_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in k6_tag:
    k6.append(i.text.split()[0].replace(',',''))
    
o6=[]
o6_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in o6_tag:
    o6.append(i.text.split()[2].replace('st','').replace('nd','').replace('rd',''))
    
f6=[]
f6_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in f6_tag:
    f6.append(i.text.split()[-1])


l6=[]
l6.append('Hyderabad')
l6=l6*443

p6=[]
p6_tag=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in p6_tag:
    p6.append(i.text.replace(',','').replace('₹',''))

# %%
driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

url='https://www.cars24.com/'
driver.get(url)

# %%
#                                                AHEMDABAD

b7=[]
b7_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in b7_tag:
    b7.append(i.text.split()[1])
    
m7=[]
m7_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in m7_tag:
    m7.append(i.text.split()[-1].replace('1.0','Wagon R 1.0').replace('3oo','XUV3oo').replace('PLUS','HECTOR PLUS').
              replace('Active','i20 Active').replace('NIOS','GRAND I10 NIOS').replace('Cross','S Cross').
              replace('country','V40 Cross Country').replace('X','Celerio X'))
    
v7=[]
v7_tag=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in v7_tag:
    v7.append(i.text.replace('Automatic','').replace('Manual',''))
    
y7=[]
y7_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in y7_tag:
    y7.append(i.text.split()[0])
    
k7=[]
k7_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in k7_tag:
    k7.append(i.text.split()[0].replace(',',''))
    
o7=[]
o7_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in o7_tag:
    o7.append(i.text.split()[2].replace('st','').replace('nd','').replace('rd',''))
    
f7=[]
f7_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in f7_tag:
    f7.append(i.text.split()[-1])


l7=[]
l7.append('Ahemdabad')
l7=l7*326

p7=[]
p7_tag=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in p7_tag:
    p7.append(i.text.replace(',','').replace('₹',''))

# %%
#                                            CHENNAI

b8=[]
b8_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in b8_tag:
    b8.append(i.text.split()[1])
    
m8=[]
m8_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in m8_tag:
    m8.append(i.text.split()[-1].replace('1.0','Wagon R 1.0').replace('Active','i20 Active').replace('Xing','Santro Xing').
             replace('NIOS','GRAND I10 NIOS').replace('PLUS','HECTOR PLUS').replace('New','Tucson'))
    
v8=[]
v8_tag=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in v8_tag:
    v8.append(i.text.replace('Automatic','').replace('Manual','')) 
    
y8=[]
y8_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in y8_tag:
    y8.append(i.text.split()[0])
    
k8=[]
k8_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in k8_tag:
    k8.append(i.text.split()[0].replace(',',''))
    
o8=[]
o8_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in o8_tag:
    o8.append(i.text.split()[2].replace('st','').replace('nd','').replace('rd',''))
    
f8=[]
f8_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in f8_tag:
    f8.append(i.text.split()[-1])

l8=[]
l8.append('Chennai')
l8=l8*467

p8=[]
p8_tag=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in p8_tag:
    p8.append(i.text.replace(',','').replace('₹',''))

# %%
#                                         KOLKATA

b9=[]
b9_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in b9_tag:
    b9.append(i.text.split()[1])
    
m9=[]
m9_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in m9_tag:
    m9.append(i.text.split()[-1].replace('1.0','Wagon R 1.0').replace('3oo','XUV3oo').replace('NIOS','GRAND I10 NIOS').
             replace('Active','i20 Active').replace('Aspire','Figo Aspire'))
    
v9=[]
v9_tag=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in v9_tag:
    v9.append(i.text.replace('Automatic','').replace('Manual','')) 
    
y9=[]
y9_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in y9_tag:
    y9.append(i.text.split()[0])
    
k9=[]
k9_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in k9_tag:
    k9.append(i.text.split()[0].replace(',',''))
    
o9=[]
o9_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in o9_tag:
    o9.append(i.text.split()[2].replace('st','').replace('nd','').replace('rd',''))
    
f9=[]
f9_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in f9_tag:
    f9.append(i.text.split()[-1])

l9=[]
l9.append('Kolkata')
l9=l9*240

p9=[]
p9_tag=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in p9_tag:
    p9.append(i.text.replace(',','').replace('₹',''))

# %%
#                                       GURGAON

b10=[]
b10_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in b10_tag:
    b10.append(i.text.split()[1])
    
m10=[]
m10_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in m10_tag:
    m10.append(i.text.split()[-1].replace('1.0','Wagon R 1.0').replace('PLUS','HECTOR PLUS').replace('NIOS','GRAND I10 NIOS').
              replace('Cross','S Cross').replace('Aspire','Figo Aspire').replace('Class','Benz').replace('New','Tucson'))
    
v10=[]
v10_tag=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in v10_tag:
    v10.append(i.text.replace('Automatic','').replace('Manual','')) 
    
y10=[]
y10_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in y10_tag:
    y10.append(i.text.split()[0])
    
k10=[]
k10_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in k10_tag:
    k10.append(i.text.split()[0].replace(',',''))
    
o10=[]
o10_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in o10_tag:
    o10.append(i.text.split()[2].replace('st','').replace('nd','').replace('rd',''))
    
f10=[]
f10_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in f10_tag:
    f10.append(i.text.split()[-1])


l10=[]
l10.append('Gurgaon')
l10=l10*540

p10=[]
p10_tag=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in p10_tag:
    p10.append(i.text.replace(',','').replace('₹',''))

# %%
#                                         CHANDIGARH

b11=[]
b11_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in b11_tag:
    b11.append(i.text.split()[1])
    
m11=[]
m11_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in m11_tag:
    m11.append(i.text.split()[-1].replace('1.0','Wagon R 1.0').replace('PLUS','HECTOR PLUS').replace('NIOS','GRAND I10 NIOS'))
    
v11=[]
v11_tag=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in v11_tag:
    v11.append(i.text.replace('Automatic','').replace('Manual','')) 
    
y11=[]
y11_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in y11_tag:
    y11.append(i.text.split()[0])
    
k11=[]
k11_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in k11_tag:
    k11.append(i.text.split()[0].replace(',',''))
    
o11=[]
o11_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in o11_tag:
    o11.append(i.text.split()[2].replace('st','').replace('nd','').replace('rd',''))
    
f11=[]
f11_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in f11_tag:
    f11.append(i.text.split()[-1])


l11=[]
l11.append('Chandigarh')
l11=l11*162

p11=[]
p11_tag=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in p11_tag:
    p11.append(i.text.replace(',','').replace('₹',''))

# %%
#                                        JAIPUR

b12=[]
b12_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in b12_tag:
    b12.append(i.text.split()[1])
    
m12=[]
m12_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in m12_tag:
    m12.append(i.text.split()[-1].replace('1.0','Wagon R 1.0').replace('X','Celerio').replace('NIOS','GRAND I10 NIOS').
              replace('K10','Alto K10'))
    
v12=[]
v12_tag=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in v12_tag:
    v12.append(i.text.replace('Automatic','').replace('Manual','')) 
    
y12=[]
y12_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in y12_tag:
    y12.append(i.text.split()[0])
    
k12=[]
k12_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in k12_tag:
    k12.append(i.text.split()[0].replace(',',''))
    
o12=[]
o12_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in o12_tag:
    o12.append(i.text.split()[2].replace('st','').replace('nd','').replace('rd',''))
    
f12=[]
f12_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in f12_tag:
    f12.append(i.text.split()[-1])


l12=[]
l12.append('Jaipur')
l12=l12*98

p12=[]
p12_tag=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in p12_tag:
    p12.append(i.text.replace(',','').replace('₹',''))

# %%
#                                              BHOPAL

b13=[]
b13_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in b13_tag:
    b13.append(i.text.split()[1])
    
m13=[]
m13_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in m13_tag:
    m13.append(i.text.split()[-1].replace('1.0','Wagon R 1.0').replace('NIOS','GRAND I10 NIOS'))
            
v13=[]
v13_tag=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in v13_tag:
    v13.append(i.text.replace('Automatic','').replace('Manual','')) 
    
y13=[]
y13_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in y13_tag:
    y13.append(i.text.split()[0])
    
k13=[]
k13_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in k13_tag:
    k13.append(i.text.split()[0].replace(',',''))
    
o13=[]
o13_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in o13_tag:
    o13.append(i.text.split()[2].replace('st','').replace('nd','').replace('rd',''))
    
f13=[]
f13_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in f13_tag:
    f13.append(i.text.split()[-1])


l13=[]
l13.append('Bhopal')
l13=l13*120

p13=[]
p13_tag=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in p13_tag:
    p13.append(i.text.replace(',','').replace('₹',''))

# %%
#                                            LUCKNOW

b14=[]
b14_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in b14_tag:
    b14.append(i.text.split()[1])
    
m14=[]
m14_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in m14_tag:
    m14.append(i.text.split()[-1].replace('NIOS','GRAND I10 NIOS').replace('Aspire','Figo Aspire').
               replace('PLUS','HECTOR PLUS'))
            
v14=[]
v14_tag=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in v14_tag:
    v14.append(i.text.replace('Automatic','').replace('Manual','')) 
    
y14=[]
y14_tag=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in y14_tag:
    y14.append(i.text.split()[0])
    
k14=[]
k14_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in k14_tag:
    k14.append(i.text.split()[0].replace(',',''))
    
o14=[]
o14_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in o14_tag:
    o14.append(i.text.split()[2].replace('st','').replace('nd','').replace('rd',''))
    
f14=[]
f14_tag=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in f14_tag:
    f14.append(i.text.split()[-1])


l14=[]
l14.append('Lucknow')
l14=l14*120

p14=[]
p14_tag=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in p14_tag:
    p14.append(i.text.replace(',','').replace('₹',''))

# %%
# Add all the data corresponding to their columns

b=b1+b2+b3+b4+b5+b6+b7+b8+b9+b10+b11+b12+b13+b14
m=m1+m2+m3+m4+m5+m6+m7+m8+m9+m10+m11+m12+m13+m14
v=v1+v2+v3+v4+v5+v6+v7+v8+v9+v10+v11+v12+v13+v14
y=y1+y2+y3+y4+y5+y6+y7+y8+y9+y10+y11+y12+y13+y14
k=k1+k2+k3+k4+k5+k6+k7+k8+k9+k10+k11+k12+k13+k14
f=f1+f2+f3+f4+f5+f6+f7+f8+f9+f10+f11+f12+f13+f14
o=o1+o2+o3+o4+o5+o6+o7+o8+o9+o10+o11+o12+o13+o14
l=l1+l2+l3+l4+l5+l6+l7+l8+l9+l10+l11+l12+l13+l14
p=p1+p2+p3+p4+p5+p6+p7+p8+p9+p10+p11+p12+p13+p14

# %% [markdown]
#                                           Create DataFrame

# %%
Used_Cars_Data=pd.DataFrame({'Brand':b,'Model':m,'Variant':v,'Manufacturing_Year':y,'Driven_Kilometer':k,'Fuel':f,
                             'Number of Owner':o,'Location':l,'Price':p})
Used_Cars_Data
# Out:
#         Brand   Model                 Variant Manufacturing_Year  \
# 0     Hyundai     i10           ERA 1.1 IRDE                2014
# 1     Hyundai     i10  SPORTZ 1.2 KAPPA VTVT                2013
# 2      Maruti   Swift                    LXI                2020
# 3      Maruti   Swift                    LXI                2019
# 4         KIA  SELTOS      HTX 1.5 PETROL MT                2020
# ...       ...     ...                     ...                ...
# 5073      KIA   SONET             HTX 1.0 IMT               2020
# 5074   Maruti   Dzire                    VXI                2019
# 5075  Hyundai   Verna            1.6 SX VTVT                2018
# 5076  Hyundai     I20            MAGNA 1.2 MT               2021
# 5077   Maruti     1.0                    VXI                2018
#
#      Driven_Kilometer    Fuel Number of Owner   Location    Price
# 0               29383  Petrol               2  New Delhi   266199
# ...

# %% [markdown]
#                                           Save the data in csv format

# %%
Used_Cars_Data.to_csv('C:\\Users\\Dell\\Desktop\\Files\\Used_Cars_Data.csv',index=False)
